# %% [markdown]
# ## [Calplot](https://github.com/tomkwok/calplot)
#
# Calplot creates heatmaps from Pandas time series data.
#
# Plot Pandas time series data sampled by day in a heatmap per calendar year using matplotlib.

# %%
import pandas as pd
import calplot

# %%
f = '../data/001_raw/temixco.csv'
esolmet = pd.read_csv(f,index_col=0,parse_dates=True)
esolmet
# Out:
#                         Ib   Ig     To     RH     WS     WD         P
# time
# 2018-01-01 00:00:00    NaN  NaN  18.70  36.34  1.422  316.0  87864.11
# 2018-01-01 00:10:00  0.002  0.0  18.95  35.29  1.008  283.7  87876.37
# 2018-01-01 00:20:00  0.170  0.0  18.94  35.43  1.565  326.0  87888.64
# 2018-01-01 00:30:00  0.371  0.0  18.77  35.89  2.175  354.5  87887.21
# 2018-01-01 00:40:00  0.305  0.0  18.81  36.34  1.902  348.0  87886.91
# ...                    ...  ...    ...    ...    ...    ...       ...
# 2018-12-31 23:10:00  0.125  0.0  18.51  47.29  1.715  332.2  87484.32
# 2018-12-31 23:20:00  0.000  0.0  18.26  48.02  1.703  320.5  87470.70
# 2018-12-31 23:30:00  0.044  0.0  18.39  46.84  2.887  335.7  87455.03
# 2018-12-31 23:40:00  0.170  0.0  17.99  47.85  1.528  358.8  87470.02
# 2018-12-31 23:50:00  0.003  0.0  17.75  49.65  0.598  322.3  87467.29
#
# [52560 rows x 7 columns]

# %%
f = '../data/001_raw/RUOA.txt'
ruoa = pd.read_csv(f,index_col=0,parse_dates=True,skiprows=[0,2],sep='\t',dayfirst=True)
ruoa.rename(columns={'Temp_Avg':'To'},inplace=True)
ruoa.head()
# Out:
#                         To  RH_Avg  WSpeed_Avg  WDir_Avg  WDir_SD  WSpeed_Max  \
# TIMESTAMP
# 2019-01-01 00:00:00  18.43   45.43       1.810     2.165    4.879        2.10
# 2019-01-01 00:01:00  18.38   45.42       1.695     2.332    3.495        1.83
# 2019-01-01 00:02:00  18.41   44.96       1.663   359.200    3.131        1.78
# 2019-01-01 00:03:00  18.48   45.25       1.597   354.500    1.258        1.86
# 2019-01-01 00:04:00  18.47   45.40       1.328   349.400    8.610        1.66
#
#                      Rain_Tot  Press_Avg  Rad_Avg
# TIMESTAMP
# 2019-01-01 00:00:00       0.0   874.4158   -2.051
# 2019-01-01 00:01:00       0.0   874.4459   -2.085
# 2019-01-01 00:02:00       0.0   874.4759   -2.051
# 2019-01-01 00:03:00       0.0   874.4300   -1.915
# 2019-01-01 00:04:00       0.0   874.3703   -1.504

# %% [markdown]
# ## Energ'ia solar diaria visualizada

# %%
calplot.calplot((esolmet.Ig)*(1/6),cmap='jet')
# Out:
# (<Figure size 900x122.4 with 2 Axes>,
#  array([<AxesSubplot:ylabel='2018'>], dtype=object))

# %%
calplot.calplot(esolmet.To,how='max',cmap='jet',vmax=37 )
calplot.calplot(ruoa.To,how='max',cmap='jet',vmax=37 )
# Out:
# (<Figure size 900x122.4 with 2 Axes>,
#  array([<AxesSubplot:ylabel='2019'>], dtype=object))

# %%
ruoa
# Out:
#                         To  RH_Avg  WSpeed_Avg  WDir_Avg  WDir_SD  WSpeed_Max  \
# TIMESTAMP
# 2019-01-01 00:00:00  18.43   45.43       1.810     2.165    4.879        2.10
# 2019-01-01 00:01:00  18.38   45.42       1.695     2.332    3.495        1.83
# 2019-01-01 00:02:00  18.41   44.96       1.663   359.200    3.131        1.78
# 2019-01-01 00:03:00  18.48   45.25       1.597   354.500    1.258        1.86
# 2019-01-01 00:04:00  18.47   45.40       1.328   349.400    8.610        1.66
# ...                    ...     ...         ...       ...      ...         ...
# 2019-06-26 17:12:00  27.29   56.69       1.765    87.800   15.290        2.39
# 2019-06-26 17:13:00  27.32   56.12       2.138    68.900   22.240        3.33
# 2019-06-26 17:14:00  27.31   55.83       2.277    80.300   10.690        3.55
# 2019-06-26 17:15:00  27.28   56.07       2.588    67.930   24.210        3.50
# 2019-06-26 17:16:00  27.30   55.69       2.547    81.300    8.160        3.27
#
# ...
